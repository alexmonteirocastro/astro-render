# %% [markdown]
# # Astro chart
#
# This will showcase the rendering of an astrological chat from the JSON data

# %%
# Imports

from astro_engine import get_chart, HouseSystem, render_astrological_chart

# %%
data = get_chart(
    date="2026-01-02",
    time="15:30",
    latitude=55.6761,
    longitude=12.5683,
    house_system=HouseSystem.REGIOMONTANUS,
    timezone_IANA_id="Europe/Copenhagen",
)
# Out:
# Running: /Users/alexandrecastro/Documents/astro_dev/data-virgo/astro-render/astro_engine/swecli/main --date 2026-01-02 --time 15:30 --lat 55.6761 --lon 12.5683 --hsys R --tzid Europe/Copenhagen --json /var/folders/_0/bvmzq9r11dj54vc7qht_xsn00000gn/T/tmpdmk5le8_.json
# Exit code: 0
# STDOUT:
#  Local: 2026-01-02 15:30:00.000
# Geo:   lat=55.676100 lon=12.568300 hsys=R
# TZ:    Europe/Copenhagen
# UT:    2026-01-02 14:30:00.000
# For houses -> JD(UT1): 2461043.10416996 and Formplanets -> JD(TT): 2461043.10496741
# UT (Julian calendar): 2025-12-20 14:30:00.285
#
# Bodies (planets + nodes) — tropical, geocentric — JD(UT)=2461043.10496741
# Station threshold: |speed_lon| <= 0.0001000 deg/day
# Body         Sign        Pos              Lon(deg)    Lat(deg)    Dist(AU) SpeedLon(deg/d)    Motion House
# -------------------------------------------------------------------------------------------------------------
# ...

# %%
render_astrological_chart(data)
